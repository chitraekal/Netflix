# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
for i in df.columns:
    if df[i].nunique()!= len(df[i]):
        print(i)
        print(df[i].unique())
        print()
        print("-"*100)
        print()
# Out:
# type
# ['Movie' 'TV Show']
#
# ----------------------------------------------------------------------------------------------------
#
# director
# ['Kirsten Johnson' nan 'Julien Leclercq' ... 'Majid Al Ansari'
#  'Peter Hewitt' 'Mozez Singh']
#
# ----------------------------------------------------------------------------------------------------
#
# cast
# [nan
#  'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng'
#  'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera'
#  ...
#  'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf'
# ...

# %%
df.director=df.director.str.split(",")
df = df.explode('director').reset_index(drop=True)

# %%
df.director=df.director.str.strip()

# %%
df.shape
# Out:
# (9612, 12)

# %%
df.cast=df.cast.str.split(",")
df = df.explode('cast').reset_index(drop=True)
df.cast=df.cast.str.strip()

# %%
df.shape
# Out:
# (70812, 12)

# %%
df.country=df.country.str.split(",")
df = df.explode('country').reset_index(drop=True)
df.country=df.country.str.strip()

# %%
df.shape
# Out:
# (89415, 12)

# %%
df.listed_in=df.listed_in.str.split(",")
df = df.explode('listed_in').reset_index(drop=True)
df.listed_in=df.listed_in.str.strip()

# %%
df.shape
# Out:
# (202065, 12)

# %%
df.head()
# Out:
#   show_id     type                 title         director         cast  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson          NaN
# 1      s2  TV Show         Blood & Water              NaN   Ama Qamata
# 2      s2  TV Show         Blood & Water              NaN   Ama Qamata
# 3      s2  TV Show         Blood & Water              NaN   Ama Qamata
# 4      s2  TV Show         Blood & Water              NaN  Khosi Ngema
#
#          country          date_added  release_year rating   duration  \
# 0  United States  September 25, 2021          2020  PG-13     90 min
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 3   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 4   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
#
#                 listed_in                                        description
# ...

# %%
df.tail()
# Out:
#        show_id   type   title     director                   cast country  \
# 202060   s8807  Movie  Zubaan  Mozez Singh         Anita Shabdish   India
# 202061   s8807  Movie  Zubaan  Mozez Singh         Anita Shabdish   India
# 202062   s8807  Movie  Zubaan  Mozez Singh  Chittaranjan Tripathy   India
# 202063   s8807  Movie  Zubaan  Mozez Singh  Chittaranjan Tripathy   India
# 202064   s8807  Movie  Zubaan  Mozez Singh  Chittaranjan Tripathy   India
#
#            date_added  release_year rating duration             listed_in  \
# 202060  March 2, 2019          2015  TV-14  111 min  International Movies
# 202061  March 2, 2019          2015  TV-14  111 min      Music & Musicals
# 202062  March 2, 2019          2015  TV-14  111 min                Dramas
# 202063  March 2, 2019          2015  TV-14  111 min  International Movies
# 202064  March 2, 2019          2015  TV-14  111 min      Music & Musicals
#
#                                               description
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202065 entries, 0 to 202064
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  object
#  2   title         202065 non-null  object
#  3   director      151422 non-null  object
#  4   cast          199916 non-null  object
#  5   country       190168 non-null  object
#  6   date_added    201907 non-null  object
#  7   release_year  202065 non-null  int64
#  8   rating        201998 non-null  object
#  9   duration      202062 non-null  object
#  10  listed_in     202065 non-null  object
#  11  description   202065 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 18.5+ MB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=202065, step=1)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director        50643
# cast             2149
# country         11897
# date_added        158
# release_year        0
# rating             67
# duration            3
# listed_in           0
# description         0
# dtype: int64

# %%
df["director"] = df["director"].fillna(value=df.director.mode()[0])

# %%
df['director'].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director            0
# cast             2149
# country         11897
# date_added        158
# release_year        0
# rating             67
# duration            3
# listed_in           0
# description         0
# dtype: int64

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.rating.value_counts()
# Out:
# rating
# TV-MA       73915
# TV-14       43957
# R           25860
# PG-13       16246
# TV-PG       14926
# PG          10919
# TV-Y7        6304
# TV-Y         3665
# TV-G         2779
# NR           1573
# G            1530
# NC-17         149
# TV-Y7-FV       86
# UR             86
# 74 min          1
# 84 min          1
# 66 min          1
# Name: count, dtype: int64

# %%
np.where(df.rating=='74 min')
# Out:
# (array([126582], dtype=int64),)

# %%
np.where(df.rating=='84 min')
# Out:
# (array([131648], dtype=int64),)

# %%
np.where(df.rating=='66 min')
# Out:
# (array([131782], dtype=int64),)

# %%
df.loc[[126582,131648,131782],'rating']=[np.nan,np.nan,np.nan]

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', nan, 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.rating.isnull().sum()
# Out:
# 70

# %%
df['rating'] = df['rating'].fillna(method="ffill")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13060\1643462050.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['rating'] = df['rating'].fillna(method="ffill")

# %%
df.rating.isnull().sum()
# Out:
# 0

# %%
df.duration.value_counts()
# Out:
# duration
# 1 Season     35035
# 2 Seasons     9559
# 3 Seasons     5084
# 94 min        4343
# 106 min       4040
#              ...
# 3 min            4
# 5 min            3
# 11 min           2
# 8 min            2
# 9 min            2
# Name: count, Length: 220, dtype: int64

# %%
df.duration.isnull().sum()
# Out:
# 3

# %%
df[df['duration'].isnull()]
# Out:
#        show_id   type                                 title    director  \
# 126582   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 131648   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 131782   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#               cast        country          date_added  release_year rating  \
# 126582  Louis C.K.  United States       April 4, 2017          2017  TV-MA
# 131648  Louis C.K.  United States  September 16, 2016          2010  TV-MA
# 131782  Louis C.K.  United States     August 15, 2016          2015  TV-MA
#
#        duration listed_in                                        description
# 126582      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 131648      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 131782      NaN    Movies  The comic puts his trademark hilarious/thought...

# %%
np.where(df.duration.isnull())
# Out:
# (array([126582, 131648, 131782], dtype=int64),)

# %%
df.loc[[126582, 131648, 131782],'duration']=['74 min','84 min','66 min']

# %%
df.duration.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director            0
# cast             2149
# country         11897
# date_added        158
# release_year        0
# rating              0
# duration            0
# listed_in           0
# description         0
# dtype: int64

# %%
df.cast.isnull().sum()
# Out:
# 2149

# %%
df.cast = df.cast.fillna(df.groupby('director')['cast'].transform(lambda x:x.mode()[0] if not x.mode().empty else x)).fillna("Not mentioned")

# %%
df.cast.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#        show_id     type                 title         director  \
# 0           s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           s2  TV Show         Blood & Water  Martin Scorsese
# 2           s2  TV Show         Blood & Water  Martin Scorsese
# 3           s2  TV Show         Blood & Water  Martin Scorsese
# 4           s2  TV Show         Blood & Water  Martin Scorsese
# ...        ...      ...                   ...              ...
# 202060   s8807    Movie                Zubaan      Mozez Singh
# 202061   s8807    Movie                Zubaan      Mozez Singh
# 202062   s8807    Movie                Zubaan      Mozez Singh
# 202063   s8807    Movie                Zubaan      Mozez Singh
# 202064   s8807    Movie                Zubaan      Mozez Singh
#
#                          cast        country          date_added  \
# 0               Not mentioned  United States  September 25, 2021
# 1                  Ama Qamata   South Africa  September 24, 2021
# ...

# %%
df.country.isnull().sum()
# Out:
# 11897

# %%
mode_country_by_director = df.groupby('director')['country'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else 'Not Mentioned')

# Fill NaN values using the mode
df['country'] = df['country'].fillna(df['director'].map(mode_country_by_director))

# %%
df.country.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast              0
# country           0
# date_added      158
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
df["date_added"] = pd.to_datetime(df["date_added"],format="mixed")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202065 entries, 0 to 202064
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  object
#  2   title         202065 non-null  object
#  3   director      202065 non-null  object
#  4   cast          202065 non-null  object
#  5   country       202065 non-null  object
#  6   date_added    201907 non-null  datetime64[ns]
#  7   release_year  202065 non-null  int64
#  8   rating        202065 non-null  object
#  9   duration      202065 non-null  object
#  10  listed_in     202065 non-null  object
#  11  description   202065 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 18.5+ MB

# %%
df.date_added.isnull().sum()
# Out:
# 158

# %%
valid_dates = df.date_added[(df.date_added.dt.year >= df.release_year) & (df.date_added.dt.year==df.release_year+4)]
random_date_per_year = df.groupby('release_year')['date_added'].apply(lambda x: valid_dates.sample(1).iloc[0])
print(random_date_per_year)
# Out:
# release_year
# 1925   2019-12-01
# 1942   2019-11-16
# 1943   2020-02-26
# 1944   2018-08-16
# 1945   2019-05-18
#           ...
# 2017   2019-02-27
# 2018   2020-08-27
# 2019   2020-11-01
# 2020   2020-07-25
# 2021   2018-07-22
# Name: date_added, Length: 74, dtype: datetime64[ns]

# %%
df['date_added'] = df['date_added'].fillna(df['release_year'].map(random_date_per_year))

# %%
df.date_added.isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (202065, 12)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        show_id   type                title        director  \
# 39354    s1632  Movie           Rust Creek     Jen McGowan
# 88560    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88561    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88562    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88563    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88564    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88565    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88566    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88567    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88568    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88569    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88570    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88571    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88572    s3719  Movie      Blood Will Tell    Miguel Cohan
# 88573    s3719  Movie      Blood Will Tell    Miguel Cohan
# ...

# %%
df.drop_duplicates(keep="first",inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.reset_index()
# Out:
#          index show_id     type                 title         director  \
# 0            0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1            1      s2  TV Show         Blood & Water  Martin Scorsese
# 2            2      s2  TV Show         Blood & Water  Martin Scorsese
# 3            3      s2  TV Show         Blood & Water  Martin Scorsese
# 4            4      s2  TV Show         Blood & Water  Martin Scorsese
# ...        ...     ...      ...                   ...              ...
# 202005  202060   s8807    Movie                Zubaan      Mozez Singh
# 202006  202061   s8807    Movie                Zubaan      Mozez Singh
# 202007  202062   s8807    Movie                Zubaan      Mozez Singh
# 202008  202063   s8807    Movie                Zubaan      Mozez Singh
# 202009  202064   s8807    Movie                Zubaan      Mozez Singh
#
#                          cast        country date_added  release_year rating  \
# ...

# %%
df
# Out:
#        show_id     type                 title         director  \
# 0           s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           s2  TV Show         Blood & Water  Martin Scorsese
# 2           s2  TV Show         Blood & Water  Martin Scorsese
# 3           s2  TV Show         Blood & Water  Martin Scorsese
# 4           s2  TV Show         Blood & Water  Martin Scorsese
# ...        ...      ...                   ...              ...
# 202060   s8807    Movie                Zubaan      Mozez Singh
# 202061   s8807    Movie                Zubaan      Mozez Singh
# 202062   s8807    Movie                Zubaan      Mozez Singh
# 202063   s8807    Movie                Zubaan      Mozez Singh
# 202064   s8807    Movie                Zubaan      Mozez Singh
#
#                          cast        country date_added  release_year rating  \
# 0               Not mentioned  United States 2021-09-25          2020  PG-13
# ...

# %%
df["country"].isnull().sum()
# Out:
# 0

# %%
df["country"].unique()
# Out:
# array(['United States', 'South Africa', 'France', 'India',
#        'Not Mentioned', 'Ghana', 'Burkina Faso', 'United Kingdom',
#        'Germany', 'Ethiopia', 'Czech Republic', 'Brazil', 'Mexico',
#        'Turkey', 'Australia', 'Finland', 'China', 'Canada', 'Japan',
#        'Nigeria', 'Spain', 'Belgium', 'South Korea', 'Singapore',
#        'Philippines', 'Italy', 'Romania', 'Argentina', 'Venezuela',
#        'Hong Kong', 'Russia', '', 'Ireland', 'Nepal', 'New Zealand',
#        'Greece', 'Jordan', 'Colombia', 'Switzerland', 'Israel', 'Taiwan',
#        'Bulgaria', 'Algeria', 'Poland', 'Egypt', 'Saudi Arabia',
#        'Thailand', 'Indonesia', 'Denmark', 'Kuwait', 'Netherlands',
#        'Malaysia', 'Vietnam', 'Hungary', 'Sweden', 'Lebanon', 'Syria',
#        'Iceland', 'United Arab Emirates', 'Norway', 'Qatar', 'Mauritius',
#        'Austria', 'Cameroon', 'Palestine', 'Uruguay', 'Kenya', 'Chile',
#        'Luxembourg', 'Cambodia', 'Bangladesh', 'Portugal',
# ...

# %%
df['country'] = df['country'].replace(r'^\s*$', np.nan, regex=True)

# %%
df["country"].isnull().sum()
# Out:
# 142

# %%
df.to_excel("cleaned_netflix.xlsx", index=False)
